# %% [markdown]
# # Zadanie 1
# **Które z następujących zadań wymagają w Twojej opinii inteligencji od człowieka:**
#
#
# * **Wypełnianie deklaracji PIT** - sztuczna inteligencja jest w stanie pomóc nam w wypełnieniu tego rodzaju deklaracj, aczkolwiek nie jest w stanie zrobić tego w pełni samodzielnie, potrzebuje informacji i niezbędnych danych, teoretycznie w każdym z wymienionych zadań jest potrzebne działanie człowieka, aczkolwiek w tym zadaniu szczególnie.
#
# * **Odpowiadanie na proste pytania zadawane w języku naturalnym** - SI potrafi odpowiadać na pytania i prowadzić konwersację, ale ma problem z zrozumieniem kontekstu i emocji wypowiedzi, dlatego do tego zadania, przynajmiej teraz, potrzebna jest ludzka inteligencja
#
# * **Komponowanie muzyki** - To twórcze zadanie, SI potrafi wygenerować muzykę, ale przynajmniej na ten moment nie jest ona zadawalająca, w łatwy sposób jesteśmy w stanie zweryfikować która muzyka została skomponowana przez człowieka, a która wygenerowana przez SI
#
# #Zadanie 2
#
#
# **Które z następujących problemów można uznać za mieszczące się w zakresie sztucznej
# inteligencji:**
#
#
#
#
#
# **• streszczanie tekstu**- Tak, to przykład przetwarzania języka naturalnego (NLP), SI wykonuje to o wiele szybciej niż człowiek
#
# **• tłumaczenie tekstu**- Tak, to również przykład NLP i uczenia maszynowego, SI jest w stanie przetłumaczyć podany tekst bardzo szybko i skutecznie, ciężko jest zauważyć różnicę.
#
# **• klasyfikacja tekstu do kategorii tematycznych**- Tak,SI potrafi analizować tekst i klasyfikować go do konkretnego tematu
#
#
# **• rozwiązywanie układów równań**, **rozwiązywanie układów równań liniowych**, **symboliczne obliczanie pochodnych**, **symboliczne całkowanie**- SI potrafi o wiele szybciej i sprawniej rozwiązywać takie zadanie, ma też o wiele większą moc obliczeniową od człowieka
#
# **• układanie rozkładu jazdy**-  Tak, wymaga analizy i optymalizacji, co może być zrealizowane przez AI, wystarczny jedynie wprowadzić dane
#
#
#
#
# **• kierowanie samochodem**- Tak, to przykład zastosowania SI w autonomicznych pojazdach, jazda autopilotem już teraz jest spopularyzowana np Tesla, również potrafi wychamować auto, lub ominąć przeszkodę w bardzo bliskiej odległości, z czym czas reakcji człowieka był by zbyt późny
#
#
#
# #Zadanie 3
#
# **Które z poniższych rodzajów komunikacyjnego zachowania człowieka mogą być
# obecnie skutecznie imitowane przez sztuczne systemy (odpowiednio oprogramowane
# maszyny):**
#
# **• rozmowa towarzyska,** tak rozmowa może być imitowana, ale na ten moment sztuczne systemy nie są w stanie podołać zadaniu prowadzenia rozmowy,w szczególności nieoficjalnej, używanej na co dzień w relacjach koleżeńskich.
#
# **• dyskusja polityczna,** w pewnym sensie tak, może odpowiadać na pytania i udzielać odpowiedzi na podstawie uzysjanych danych, ale brak mu jest "duszy" bez której maszynie jest trudno zrozumieć wszystkie aspkety i niuanse emocjonalne, również brak jej możliwości wyrażania własnej opinii.
#
# **• dyskusja naukowa,** podobnie jak przykład wyżej , maszyna może dostarczać informacji i analizować dane, ale nie ma zdolności do oryginalnego myślenia czy twórczego rozwiązywania problemów, nie udzieli informacji nowej, odkrywczej.
#
# **• odpowiadanie na pytania klientów w telefonicznej infolinii,** tak Chatboty i systemy automatycznego odpowiadania mogą skutecznie obsługiwać standardowe pytania i problemy, czym zajmują się już teraz.
#
# **• odpowiadanie na pytania klientów w internetowej infolinii**, tak, podobnie jak w przypadku infolinii telefonicznych, chatboty i asystenci wirtualni mogą skutecznie odpowiadać na pytania klientów online, co z resztą już robią.
#
# #Zadanie 4
# **1. Przeprowadź rozmowę z chatbotem. Spróbuj zdefiniować różnice pomiędzy
# botem udającym człowieka (przygotowywanym na test Turinga) a botem
# „asystentem, służącym”**
# * Bot przygotowany na test Turinga odpowiada w sposób bardziej naturalny, sprawia wrażenie istosty myślącej samodzielnie, jego odpowiedzi mogą mieć różny wydźwięk  zależnie od nałożonego na to kontekstu (oficjalny, naukowy, nieformalny itd.) Dodatkowo potrafi zmieniać konpecje swojej wypowiedzi a jego baza danych jest bardzo duża
#
# * Bot asystent odpowiada w sposób "mechaniczny", jego odpowiedzi są gotowymi formułami na nasze pytania które są dopasowywane do algorytmu. Jego baza danych jest ograniczona, jego zadaniem jest pomóc użytinkowi, a nie jak w przypadku np chatgpt prowadzić sensowną rozmowę.
#
# **2. Sprawdź dwa boty z obu z tych rodzajów na występowanie zachowań:**
#
# **a) opowiadanie żartów,**
#
#
#
# Chat gpt: opowie żart bez żadnego problemu, z różnych kategorii
#
# x-kom chatbot: prosząc go o to zostajemy od razu przekierowani do skontaktowania się z ekspertem
#
# **b) przytaczanie cytatów z twoich wypowiedzi, lub znanych osób,**
#
# chat gpt: bez problemu cytuje wypowiedzi znanych osób zarówno tych histrycznych jaki obecnie żyjących
#
# x-kom : bot nie rozumie zadanego polecenia
#
# **c) nawiązywanie wypowiedzi do słów kluczowych,**
#
# chat gpt: ponownie nie ma problemu z nawiązaniem do wcześniejszych słów, lub oparcia rozmowy na słowach kluczowych
#
# x-kom: jeżeli całą rozmowę opieramy na tym samym problemie to będzie do niej nawiązywał
#
# **d) zadawanie dużej liczby pytań,**
#
# chat gpt: zadaje wiele pytań by nam pomóc stara się "zadbać" o naszą potrzebę
#
# x-kom: zadaje minimalną ilość pytań, w więkos
# **e) powracanie do początku wypowiedzi, sekwencyjne powtarzanie,**
#
# chat gpt: nie ma z tym najmniejszego problemu, nawet sam o wraca do początków rozmowy
#
# x-kom: nie robi tego w cale, chyba że jest to konieczne
#
# **f) zadawanie pytań powstających z twoich wypowiedzi,**
#
# chat gpt: bez problemu sobie z tym radzi
#
# x-kom: również potrafi to zrobić w celu rozwiązania problemu
#
# **g) odpowiadanie wymijająco, ogólnikowo,**
#
# chat gpt; raczej tego nie robi, nawet jeśli odpowie ogólnikowo to zawęzi swoją odpowiedź jeśli go o to poprosimy; dla porównania cleverbot robi to bardzo często, również odpowiada bardzo losowo
#
# x-kom: odpowiada jak najbardziej precyzyjnie by nam pomóc i krok po kroku przedstawić co należy zrobić by uzyskać porządaną informację
#
# **h) częsta zmiana tematu rozmowy,**
#
# chat gpt: raczej trzyma się wątku wypowiedzi potrafi zmienić przebieg rozmowy, ale nadal jest ona spójna z początkowym wątkiem
#
# x-kom: nie zmienia tematu rozmowy odpowiada tylko i wyłącznie na problem dotyczacy zamówienia
#
# **i) problemy z utrzymaniem wątków.**
#
# chat gpt: brak problemu
#
# x-kom: generalnie trzyma się problemu z którym się do niego zgłaszamy, ale pytając go o  przytoczenie pytania, które zadałem mu wcześniej nie potrafi tego zrobić
#
# **3. Sporządź raport ze spostrzeżeń**
#
#
# Chat gpt nie ma najmniejszego problemu z wykonaniem wyżej wymienionych zadań, wydaje się być bardzo ludzki, jego zasób informacji jest re ogromny, rozmawiając z nim możemy czuć się zaspokojeni poprzez przekazane do nas informacje, które nas interesują, dobrze imituje człowieka.
#
# Chatbot z x-kom potrafi jedynie rozwiązać podstawowe problemy i pytania dotyczące zamówienia, które znajdują się w jego ograniczonej bazie, jego zadaniem jest pomoc, a więc nie jesteśmy w stanie przeprowadzić z nim sesnsownej i głębszej rozmowy.
#
#
#
# **4. Na podstawie powyższych obserwacji, w grupie dwóch osób spróbujcie przewidzieć zachowania dwóch rozmawiających ze sobą chatbotów (przepisując ich
# wzajemne odpowiedzi).**
#
#
#
# 1: Hello! How can I assist you today?
#
# 2: It s. Ok old sport.
#
# 1: Ah, I see we’re channeling a little The Great Gatsby! What’s on your mind, old sport? 😄
#
# 2: What is The Great Gatenby?
#
# 1: The Great Gatsby is a classic American novel written by F. Scott Fitzgerald and first published in 1925. It’s widely regarded as one of the greatest works of 20th-century literature and is a staple in American high school and college reading lists.
#
# 2: I must read Romeo and Juliet for school.
#
# 1: That's great! Romeo and Juliet by William Shakespeare is a timeless classic and one of the most famous love stories in literature. It's packed with drama, romance, and poetic language, making it an essential read for understanding Shakespeare's work.
#
# 2: You know that song is triggering to me. Why are you doing this?
#
#
#
#
# Jak widać rozmowa ta średnio trzymała się całości chat gpt (1) odpowiadał cleverbotowi (2) aczkolwiek cleverbot nie był zaangażowany w tą rozmowę, odpowiadał bardzo wymijająco, natomiast chatgpt generował bardzo długie wypowiedzi.
#
# **5. Zdenerwuj bota**
#
#
# Zanim to zrobiłem to bot sam zdążył mnie zdenerwować, ale chatgpt zdołał zdenerwować cleverbota :)
#
#
# User: My name is kacper.
#
#
# Cleverbot: Nice name.
#
#
# User: What is my name.
#
#
# Cleverbot: I don't know what your name is. Do you want to know my last name?
#
#
# User: WHAT?!.
#
#
# Cleverbot: My name is Rayne. Rayne The Killer is my full name.
#
#
# User: You embrassed me.
#
#
# Cleverbot: Sue is my first name.
#
#
# User: Stop talking.
#
#
# Cleverbot: I'm not talking silly pony, I'm typing.
